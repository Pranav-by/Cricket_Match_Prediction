# %% [markdown]
# ### Convert raw cricket data into numerical signals that a neural network can actually learn from.

# %%
import pandas as pd

# %%
match_df = pd.read_csv("data/processed/match_summary_final.csv")
innings_df = pd.read_csv("data/processed/innings_summary_valid.csv")
match_df.shape,innings_df.shape
# Out:
# ((2438, 9), (4876, 6))

# %% [markdown]
# We will compute past average runs per batting team

# %%
team_avg_runs = (
    innings_df
    .groupby("batting_team")["total_runs"]
    .mean()
    .reset_index()
)

team_avg_runs.columns = ["team", "avg_runs"]
team_avg_runs.head()
# Out:
#          team    avg_runs
# 0   Africa XI  242.200000
# 1     Asia XI  237.800000
# 2   Australia  246.498915
# 3  Bangladesh  214.406349
# 4     Bermuda  155.000000

# %% [markdown]
# #### Team 1 batting strength

# %%
match_df = match_df.merge(
    team_avg_runs,
    left_on="team_1",
    right_on="team",
    how="left"
).rename(columns={"avg_runs": "team_1_avg_runs"}).drop("team", axis=1)

# %% [markdown]
# ### Team 2 batting strength

# %%
match_df = match_df.merge(
    team_avg_runs,
    left_on="team_2",
    right_on="team",
    how="left"
).rename(columns={"avg_runs": "team_2_avg_runs"}).drop("team", axis=1)

# %%
match_df["team_1_won_toss"] = (
    match_df["toss_winner"] == match_df["team_1"]
).astype(int)

# %% [markdown]
# ### Toss winner Feature

# %%
match_df["team_1_batted_first"] = (
    (match_df["team_1_won_toss"] == 1) &
    (match_df["toss_decision"] == "bat")
).astype(int)

# %% [markdown]
# ### Batting First feature

# %%
match_df["team_1_batted_first"] = (
    (
        (match_df["toss_winner"] == match_df["team_1"]) &
        (match_df["toss_decision"] == "bat")
    ) |
    (
        (match_df["toss_winner"] == match_df["team_2"]) &
        (match_df["toss_decision"] == "field")
    )
).astype(int)

# %%
from sklearn.preprocessing import LabelEncoder

venue_encoder = LabelEncoder()
match_df["venue_encoded"] = venue_encoder.fit_transform(match_df["venue"])
match_df
# Out:
#       match_id                    team_1                    team_2  \
# 0        64814               New Zealand                     India
# 1        64815                     India               New Zealand
# 2        64816                     India               New Zealand
# 3        64817               New Zealand                     India
# 4        64819                     India               New Zealand
# ...        ...                       ...                       ...
# 2433   1507885      United Arab Emirates  United States of America
# 2434   1507886                     Nepal      United Arab Emirates
# 2435   1507887                     Nepal  United States of America
# 2436   1507888  United States of America      United Arab Emirates
# 2437   1507889                     Nepal      United Arab Emirates
#
#       team_1_runs  team_2_runs                    winner  \
# 0             254          219               New Zealand
# 1             108          109               New Zealand
# 2             122          123               New Zealand
# 3             168          169                     India
# 4             122          125               New Zealand
# ...           ...          ...                       ...
# 2433          211          213  United States of America
# 2434          233          237      United Arab Emirates
# 2435          271          273  United States of America
# 2436          292           49  United States of America
# 2437          239          243      United Arab Emirates
#
#                                     venue               toss_winner  \
# 0                     McLean Park, Napier                     India
# 1              Jade Stadium, Christchurch                     India
# 2                 Davies Park, Queenstown               New Zealand
# 3             Westpac Stadium, Wellington               New Zealand
# 4                  Westpac Park, Hamilton               New Zealand
# ...                                   ...                       ...
# 2433  Dubai International Cricket Stadium  United States of America
# 2434                   ICC Academy, Dubai                     Nepal
# 2435                   ICC Academy, Dubai  United States of America
# 2436  Dubai International Cricket Stadium      United Arab Emirates
# 2437                   ICC Academy, Dubai      United Arab Emirates
#
#      toss_decision  team_1_avg_runs  team_2_avg_runs  team_1_won_toss  \
# 0            field       234.997319       247.694000                0
# 1              bat       247.694000       234.997319                1
# 2            field       247.694000       234.997319                0
# 3              bat       234.997319       247.694000                1
# 4            field       247.694000       234.997319                0
# ...            ...              ...              ...              ...
# 2433         field       199.614679       221.647887                0
# 2434           bat       201.026667       199.614679                1
# 2435         field       201.026667       221.647887                0
# 2436         field       221.647887       199.614679                0
# 2437         field       201.026667       199.614679                0
#
#       team_1_batted_first  venue_encoded
# 0                       1            159
# 1                       1            119
# 2                       1             67
# 3                       1            299
# 4                       1            297
# ...                   ...            ...
# 2433                    1             75
# 2434                    1            111
# 2435                    1            111
# 2436                    1             75
# 2437                    1            111
#
# [2438 rows x 14 columns]

# %% [markdown]
# ### win prediction target

# %%
match_df["team_1_won"] = (
    match_df["winner"] == match_df["team_1"]
).astype(int)

y_win = match_df["team_1_won"]
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2433    0
# 2434    0
# 2435    0
# 2436    1
# 2437    0
# Name: team_1_won, Length: 2438, dtype: int64

# %%
y_runs = match_df[["team_1_runs", "team_2_runs"]]
y_runs
# Out:
#       team_1_runs  team_2_runs
# 0             254          219
# 1             108          109
# 2             122          123
# 3             168          169
# 4             122          125
# ...           ...          ...
# 2433          211          213
# 2434          233          237
# 2435          271          273
# 2436          292           49
# 2437          239          243
#
# [2438 rows x 2 columns]

# %%
match_df.head()
# Out:
#    match_id       team_1       team_2  team_1_runs  team_2_runs       winner  \
# 0     64814  New Zealand        India          254          219  New Zealand
# 1     64815        India  New Zealand          108          109  New Zealand
# 2     64816        India  New Zealand          122          123  New Zealand
# 3     64817  New Zealand        India          168          169        India
# 4     64819        India  New Zealand          122          125  New Zealand
#
#                          venue  toss_winner toss_decision  team_1_avg_runs  \
# 0          McLean Park, Napier        India         field       234.997319
# 1   Jade Stadium, Christchurch        India           bat       247.694000
# 2      Davies Park, Queenstown  New Zealand         field       247.694000
# 3  Westpac Stadium, Wellington  New Zealand           bat       234.997319
# 4       Westpac Park, Hamilton  New Zealand         field       247.694000
#
#    team_2_avg_runs  team_1_won_toss  team_1_batted_first  venue_encoded  \
# 0       247.694000                0                    1            159
# 1       234.997319                1                    1            119
# 2       234.997319                0                    1             67
# 3       247.694000                1                    1            299
# 4       234.997319                0                    1            297
#
#    team_1_won
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0

# %% [markdown]
# ## Final Feature Matrix

# %%
feature_cols =[
    "team_1_avg_runs",
    "team_2_avg_runs",
    "team_1_won_toss",
    "team_1_batted_first",
    "venue_encoded",
]
X= match_df[feature_cols]

# %%
X.isna().sum()
# Out:
# team_1_avg_runs        0
# team_2_avg_runs        0
# team_1_won_toss        0
# team_1_batted_first    0
# venue_encoded          0
# dtype: int64

# %%
X.head()
# Out:
#    team_1_avg_runs  team_2_avg_runs  team_1_won_toss  team_1_batted_first  \
# 0       234.997319       247.694000                0                    1
# 1       247.694000       234.997319                1                    1
# 2       247.694000       234.997319                0                    1
# 3       234.997319       247.694000                1                    1
# 4       247.694000       234.997319                0                    1
#
#    venue_encoded
# 0            159
# 1            119
# 2             67
# 3            299
# 4            297

# %%
match_df.to_csv(
    "data/processed/match_features_step4.csv",index=False
)
print("Features csv file saved successfully")
# Out:
# Features csv file saved successfully

# %% [markdown]
# # Step 5 -> Add team recent match avg

# %%
import pandas as pd

match_df = pd.read_csv("data/processed/match_features_step4.csv")
innings_df = pd.read_csv("data/processed/innings_summary_valid.csv")

# %%
team_match_runs = innings_df[
    ["match_id", "batting_team", "total_runs"]
].copy()

team_match_runs = team_match_runs.rename(
    columns={"batting_team": "team"}
)

# %%
match_df["match_order"] = range(len(match_df))

team_match_runs = team_match_runs.merge(
    match_df[["match_id", "match_order"]],
    on="match_id",
    how="left"
)

# %%
team_match_runs = team_match_runs.sort_values(
    by=["team", "match_order"]
)

# %%
team_match_runs["recent_avg_runs"] = (
    team_match_runs
    .groupby("team")["total_runs"]
    .shift(1)
    .rolling(window=7, min_periods=1)
    .mean()
)

# %%
team_match_runs.head()
# Out:
#      match_id       team  total_runs  match_order  recent_avg_runs
# 470    216271  Africa XI         198          235              NaN
# 472    216669  Africa XI         106          236       198.000000
# 945    289107  Africa XI         283          472       152.000000
# 947    289108  Africa XI         306          473       195.666667
# 949    289110  Africa XI         318          474       223.250000

# %%
match_df = match_df.merge(
    team_match_runs[["match_id", "team", "recent_avg_runs"]],
    left_on=["match_id", "team_1"],
    right_on=["match_id", "team"],
    how="left"
).rename(columns={"recent_avg_runs": "team_1_recent_avg_runs"}) \
 .drop("team", axis=1)

# %%
match_df = match_df.merge(
    team_match_runs[["match_id", "team", "recent_avg_runs"]],
    left_on=["match_id", "team_2"],
    right_on=["match_id", "team"],
    how="left"
).rename(columns={"recent_avg_runs": "team_2_recent_avg_runs"}) \
 .drop("team", axis=1)

# %%
match_df.head()
# Out:
#    match_id       team_1       team_2  team_1_runs  team_2_runs       winner  \
# 0     64814  New Zealand        India          254          219  New Zealand
# 1     64815        India  New Zealand          108          109  New Zealand
# 2     64816        India  New Zealand          122          123  New Zealand
# 3     64817  New Zealand        India          168          169        India
# 4     64819        India  New Zealand          122          125  New Zealand
#
#                          venue  toss_winner toss_decision  team_1_avg_runs  \
# 0          McLean Park, Napier        India         field       234.997319
# 1   Jade Stadium, Christchurch        India           bat       247.694000
# 2      Davies Park, Queenstown  New Zealand         field       247.694000
# 3  Westpac Stadium, Wellington  New Zealand           bat       234.997319
# 4       Westpac Park, Hamilton  New Zealand         field       247.694000
#
#    team_2_avg_runs  team_1_won_toss  team_1_batted_first  venue_encoded  \
# 0       247.694000                0                    1            159
# 1       234.997319                1                    1            119
# 2       234.997319                0                    1             67
# 3       247.694000                1                    1            299
# 4       234.997319                0                    1            297
#
#    team_1_won  match_order  team_1_recent_avg_runs  team_2_recent_avg_runs
# 0           1            0              229.166667              159.200000
# 1           0            1              184.800000              224.500000
# 2           0            2              171.600000              208.500000
# 3           0            3              189.833333              167.600000
# 4           0            4              178.200000              180.333333

# %% [markdown]
# Fill early NaNs (first few matches)

# %%
match_df["team_1_recent_avg_runs"] = match_df["team_1_recent_avg_runs"].fillna(
    match_df["team_1_avg_runs"]
)

match_df["team_2_recent_avg_runs"] = match_df["team_2_recent_avg_runs"].fillna(
    match_df["team_2_avg_runs"]
)

# %%
match_df.head()
# Out:
#    match_id       team_1       team_2  team_1_runs  team_2_runs       winner  \
# 0     64814  New Zealand        India          254          219  New Zealand
# 1     64815        India  New Zealand          108          109  New Zealand
# 2     64816        India  New Zealand          122          123  New Zealand
# 3     64817  New Zealand        India          168          169        India
# 4     64819        India  New Zealand          122          125  New Zealand
#
#                          venue  toss_winner toss_decision  team_1_avg_runs  \
# 0          McLean Park, Napier        India         field       234.997319
# 1   Jade Stadium, Christchurch        India           bat       247.694000
# 2      Davies Park, Queenstown  New Zealand         field       247.694000
# 3  Westpac Stadium, Wellington  New Zealand           bat       234.997319
# 4       Westpac Park, Hamilton  New Zealand         field       247.694000
#
#    team_2_avg_runs  team_1_won_toss  team_1_batted_first  venue_encoded  \
# 0       247.694000                0                    1            159
# 1       234.997319                1                    1            119
# 2       234.997319                0                    1             67
# 3       247.694000                1                    1            299
# 4       234.997319                0                    1            297
#
#    team_1_won  match_order  team_1_recent_avg_runs  team_2_recent_avg_runs
# 0           1            0              229.166667              159.200000
# 1           0            1              184.800000              224.500000
# 2           0            2              171.600000              208.500000
# 3           0            3              189.833333              167.600000
# 4           0            4              178.200000              180.333333

# %%
feature_cols = [
    "team_1_avg_runs",
    "team_2_avg_runs",
    "team_1_recent_avg_runs",
    "team_2_recent_avg_runs",
    "team_1_won_toss",
    "team_1_batted_first",
    "venue_encoded"
]

X = match_df[feature_cols]

# %%
X.head()
# Out:
#    team_1_avg_runs  team_2_avg_runs  team_1_recent_avg_runs  \
# 0       234.997319       247.694000              229.166667
# 1       247.694000       234.997319              184.800000
# 2       247.694000       234.997319              171.600000
# 3       234.997319       247.694000              189.833333
# 4       247.694000       234.997319              178.200000
#
#    team_2_recent_avg_runs  team_1_won_toss  team_1_batted_first  venue_encoded
# 0              159.200000                0                    1            159
# 1              224.500000                1                    1            119
# 2              208.500000                0                    1             67
# 3              167.600000                1                    1            299
# 4              180.333333                0                    1            297

# %%
match_df.to_csv(
    "data/processed/match_features_step5.csv",
    index=False
)

print("Step 5 completed: recent form features added")
# Out:
# Step 5 completed: recent form features added
